# %%
# %sql
CREATE OR REPLACE TABLE ecommerce_orders
(
order_id INT,
customer_name STRING,
city STRING,
product STRING,
quantity INT,
price INT,
order_status STRING
)
USING DELTA;


INSERT INTO ecommerce_orders VALUES
(101,'Amit Sharma','Hyderabad','Laptop',1,75000,'Placed'),
(102,'Priya Reddy','Bangalore','Mobile',2,30000,'Placed'),
(103,'Rohit Mehta','Mumbai','Headphones',3,2000,'Shipped'),
(104,'Sneha Iyer','Chennai','Laptop',1,72000,'Placed'),
(105,'Karan Patel','Ahmedabad','Tablet',2,25000,'Cancelled'),
(106,'Ananya Das','Kolkata','Mobile',1,28000,'Placed'),
(107,'Vikram Singh','Delhi','Camera',1,55000,'Placed'),
(108,'Meera Nair','Bangalore','Laptop',1,80000,'Placed');
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>8</td><td>8</td></tr></tbody></table></div>

# %% [markdown]
# PART 1 — INSERT Exercises
#
# 1. Insert a new order for Rahul Verma from Mumbai buying a Tablet worth 27000.

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(109,'Rahul Verma','Mumbai','Tablet',1,27000,'Placed')
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 2. Insert two new orders:\
# Arjun Nair buying Mobile\
# Kavya Reddy buying Laptop

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(110,'Arjun Nair','Bangalore','Mobile',2,70000,'Cancelled'),
(111,'Kavya Reddy','Mumbai','Laptopt',1,27000,'Placed')
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>2</td><td>2</td></tr></tbody></table></div>

# %% [markdown]
# 3. Insert an order with status Shipped.

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(112,'John Maxwell','Chennaii','Smart Watch',2,30000,'Shipped')
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 4. Insert an order with quantity 5 headphones.

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(113, "Stuart Danny", 'Delhi', 'Headphones', 5, 5000, 'Shipped')
;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 5. Insert three new orders for Hyderabad customers.

# %%
# %sql
INSERT INTO ecommerce_orders VALUES
(114,'Hemesh','Bangalore','Headsets',2, 2000, 'Placeed'),
(115,'Ajay','Bangalore','Earphones',1, 2000, 'Cancelled'),
(116,'Priya','Bangalore','iPad',1, 100000, "Placed");
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>3</td><td>3</td></tr></tbody></table></div>

# %% [markdown]
# PART 2 — UPDATE Exercises
#
# 1. Change order_status of order 101 to Shipped.

# %%
# %sql
UPDATE ecommerce_orders
SET order_status = 'Shipped'
WHERE order_id = 101
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 2. Increase quantity of order 102 by 1.

# %%
# %sql
UPDATE ecommerce_orders
SET quantity = quantity + 1
WHERE order_id = 102
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 3. Change price of all Laptop orders to 78000.

# %%
# %sql
UPDATE ecommerce_orders
SET price = 78000
WHERE product = "Laptop"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %% [markdown]
# 4. Update city of Amit Sharma to Secunderabad.

# %%
# %sql

UPDATE ecommerce_orders
SET city = 'Secunderabad'
WHERE customer_name = 'Amit Sharma'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>1</td></tr></tbody></table></div>

# %% [markdown]
# 5. Change order_status to Delivered where product = Mobile.

# %%
# %sql

UPDATE ecommerce_orders
 SET order_status = 'Delivered' WHERE product = 'Mobile';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>3</td></tr></tbody></table></div>

# %% [markdown]
# 6. Update price of Headphones to 2500.

# %%
# %sql
UPDATE ecommerce_orders
SET  price = 2500
WHERE product = "Headphones"
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %% [markdown]
# 7. Increase price of all Tablet products by 1000.

# %%
# %sql
UPDATE ecommerce_orders
SET price = price + 1000
WHERE product = 'Tablet'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>2</td></tr></tbody></table></div>

# %% [markdown]
# 8. Change order_status of orders from Bangalore to Processing.

# %%
# %sql
UPDATE ecommerce_orders
SET order_status = 'Processing'
WHERE city = 'Bangalore'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>6</td></tr></tbody></table></div>

# %% [markdown]
# 9. Update quantity to 2 where quantity = 1.

# %%
# %sql
UPDATE ecommerce_orders
SET quantity = 2
WHERE quantity = 1
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>9</td></tr></tbody></table></div>

# %% [markdown]
# 10. Change city Ahmedabad to Surat.

# %%
# %sql
UPDATE ecommerce_orders
SET city = 'Ahmedabad'
WHERE city = 'Surat'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th></tr></thead><tbody><tr><td>0</td></tr></tbody></table></div>

# %% [markdown]
# PART 3 — DELETE Exercises
#
# 1. Delete orders where order_status = Cancelled.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE order_status = 'Cancelled') AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 2. Delete orders where quantity > 3.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE quantity > 3) AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 3. Delete orders where product = Camera.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE product = 'Camera') AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 4. Delete orders placed from Kolkata.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE city = 'Kolkata') AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 5. Delete orders where price < 5000.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE price < 5000) AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 6. Delete orders where customer_name starts with A.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE customer_name LIKE 'A%') AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 7. Delete all Tablet orders.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE product = 'Tablet') AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 8. Delete orders where city = Mumbai AND quantity = 1.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE city = 'Mumbai' AND quantity = 1) AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 9. Delete orders with price greater than 80000.

# %%
# %sql
MERGE INTO retail_orders AS target
USING (SELECT * FROM retail_orders WHERE price > 80000) AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 10. Delete last inserted order.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING (SELECT MAX(order_id) as max_id FROM ecommerce_orders) AS source
ON target.order_id = source.max_id
WHEN MATCHED THEN DELETE;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>1</td><td>0</td><td>1</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# PART 4 — MERGE / UPSERT Exercises

# %%
# %sql
CREATE OR REPLACE TEMP VIEW incoming_orders AS
SELECT * FROM VALUES
(102,'Priya Reddy','Bangalore','Mobile',4,30000,'Delivered'),
(104,'Sneha Iyer','Chennai','Laptop',1,72000,'Shipped'),
(109,'Rahul Verma','Mumbai','Tablet',2,26000,'Placed'),
(110,'Divya Menon','Kochi','Mobile',1,27000,'Placed'),
(111,'Farhan Ali','Hyderabad','Laptop',1,79000,'Placed')
AS incoming_orders(order_id,customer_name,city,product,quantity,price,order_status);

# %% [markdown]
# Exercises
#
# 1. Merge incoming_orders into ecommerce_orders.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET *
WHEN NOT MATCHED THEN
  INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 2. Update matching orders using WHEN MATCHED.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET 
    target.customer_name = source.customer_name,
    target.city = source.city,
    target.product = source.product,
    target.quantity = source.quantity,
    target.price = source.price,
    target.order_status = source.order_status;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 3. Insert new orders using WHEN NOT MATCHED.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN NOT MATCHED THEN
  INSERT (order_id, customer_name, city, product, quantity, price, order_status)
  VALUES (source.order_id, source.customer_name, source.city, source.product, source.quantity, source.price, source.order_status);
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 4. After merge, list orders sorted by order_id.

# %%
# %sql
SELECT * FROM ecommerce_orders 
ORDER BY order_id ASC;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>order_id</th><th>customer_name</th><th>city</th><th>product</th><th>quantity</th><th>price</th><th>order_status</th></tr></thead><tbody><tr><td>101</td><td>Amit Sharma</td><td>Secunderabad</td><td>Laptop</td><td>2</td><td>78000</td><td>Shipped</td></tr><tr><td>102</td><td>Priya Reddy</td><td>Bangalore</td><td>Mobile</td><td>4</td><td>30000</td><td>Delivered</td></tr><tr><td>103</td><td>Rohit Mehta</td><td>Mumbai</td><td>Headphones</td><td>3</td><td>2500</td><td>Shipped</td></tr><tr><td>104</td><td>Sneha Iyer</td><td>Chennai</td><td>Laptop</td><td>1</td><td>72000</td><td>Shipped</td></tr><tr><td>105</td><td>Karan Patel</td><td>Ahmedabad</td><td>Tablet</td><td>2</td><td>26000</td><td>Cancelled</td></tr><tr><td>106</td><td>Ananya Das</td><td>Kolkata</td><td>Mobile</td><td>2</td><td>28000</td><td>Delivered</td></tr><tr><td>107</td><td>Vikram Singh</td><td>Delhi</td><td>Camera</td><td>2</td><td>55000</td><td>Placed</td></tr><tr><td>108</td><td>Meera Nair</td><td>Bangalore</td><td>Laptop</td><td>2</td><td>78000</td><td>Processing</td></tr><tr><td>109</td><td>Rahul Verma</td><td>Mumbai</td><td>Tablet</td><td>2</td><td>26000</td><td>Placed</td></tr><tr><td>110</td><td>Divya Menon</td><td>Kochi</td><td>Mobile</td><td>1</td><td>27000</td><td>Placed</td></tr><tr><td>111</td><td>Farhan Ali</td><td>Hyderabad</td><td>Laptop</td><td>1</td><td>79000</td><td>Placed</td></tr><tr><td>112</td><td>John Maxwell</td><td>Chennaii</td><td>Smart Watch</td><td>2</td><td>30000</td><td>Shipped</td></tr><tr><td>113</td><td>Stuart Danny</td><td>Delhi</td><td>Headphones</td><td>5</td><td>2500</td><td>Shipped</td></tr><tr><td>114</td><td>Hemesh</td><td>Bangalore</td><td>Headsets</td><td>2</td><td>2000</td><td>Processing</td></tr><tr><td>115</td><td>Ajay</td><td>Bangalore</td><td>Earphones</td><td>2</td><td>2000</td><td>Processing</td></tr></tbody></table></div>

# %% [markdown]
# 5. Identify which rows were inserted vs updated.

# %%
# %sql
DESCRIBE HISTORY ecommerce_orders;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>version</th><th>timestamp</th><th>userId</th><th>userName</th><th>operation</th><th>operationParameters</th><th>job</th><th>notebook</th><th>queryHistoryStatementId</th><th>clusterId</th><th>readVersion</th><th>isolationLevel</th><th>isBlindAppend</th><th>operationMetrics</th><th>userMetadata</th><th>engineInfo</th></tr></thead><tbody><tr><td>124</td><td>2026-04-30T07:36:41.001Z</td><td>140745818471898</td><td>nfazuser5819_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>MERGE</td><td>Map(predicate -> ["(order_id#59043 = order_id#59029)"], clusterBy -> [], matchedPredicates -> [], statsOnLoad -> false, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [{"actionType":"insert"}])</td><td>null</td><td>List(2495551528389470)</td><td>59df3735-d52b-4494-ba60-fcb0cdb19882</td><td>0430-040952-xw8iy1fq-v2n</td><td>123</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 0, numTargetBytesAdded -> 0, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 0, numTargetRowsMatchedUpdated -> 0, executionTimeMs -> 520, materializeSourceTimeMs -> 3, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 0, numTargetRowsUpdated -> 0, numOutputRows -> 0, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 5, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 502)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>123</td><td>2026-04-30T07:36:41.000Z</td><td>140745818471898</td><td>nfazuser5819_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td><td>List(2495551528389470)</td><td>1ac136a6-a6a0-4ef2-85ec-b9c0cac63bd6</td><td>0430-040952-xw8iy1fq-v2n</td><td>122</td><td>SnapshotIsolation</td><td>false</td><td>Map(numRemovedFiles -> 6, numRemovedBytes -> 12286, p25FileSize -> 2629, numDeletionVectorsRemoved -> 1, minFileSize -> 2629, numAddedFiles -> 1, maxFileSize -> 2629, p75FileSize -> 2629, p50FileSize -> 2629, numAddedBytes -> 2629)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>122</td><td>2026-04-30T07:36:40.000Z</td><td>140745818471898</td><td>nfazuser5819_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>MERGE</td><td>Map(predicate -> ["(order_id#58454 = order_id#58440)"], clusterBy -> [], matchedPredicates -> [{"actionType":"update"}], statsOnLoad -> false, notMatchedBySourcePredicates -> [], notMatchedPredicates -> [])</td><td>null</td><td>List(2495551528389470)</td><td>1ac136a6-a6a0-4ef2-85ec-b9c0cac63bd6</td><td>0430-040952-xw8iy1fq-v2n</td><td>121</td><td>WriteSerializable</td><td>false</td><td>Map(numTargetRowsCopied -> 0, numTargetRowsDeleted -> 0, numTargetFilesAdded -> 5, numTargetBytesAdded -> 9657, numTargetBytesRemoved -> 0, numTargetDeletionVectorsAdded -> 1, numTargetRowsMatchedUpdated -> 5, executionTimeMs -> 1774, materializeSourceTimeMs -> 56, numTargetRowsInserted -> 0, numTargetRowsMatchedDeleted -> 0, numTargetDeletionVectorsUpdated -> 0, scanTimeMs -> 599, numTargetRowsUpdated -> 5, numOutputRows -> 5, numTargetDeletionVectorsRemoved -> 0, numTargetRowsNotMatchedBySourceUpdated -> 0, numTargetChangeFilesAdded -> 0, numSourceRows -> 5, numTargetFilesRemoved -> 0, numTargetRowsNotMatchedBySourceDeleted -> 0, rewriteTimeMs -> 1101)</td><td>null</td><td>Databricks-Runtime/18.1.x-photon-scala2.13</td></tr><tr><td>121</td><td>2026-04-30T07:36:37.000Z</td><td>140745818471898</td><td>nfazuser5819_mml.local@karthikirisoutlook.onmicrosoft.com</td><td>OPTIMIZE</td><td>Map(predicate -> [], auto -> true, clusterBy -> [], zOrderBy -> [], batchId -> 0)</td><td>null</td> ...

# %% [markdown]
# 6. Modify merge logic to update only order_status.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET target.order_status = source.order_status;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 7. Write merge logic to update quantity only when it increases.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN MATCHED AND source.quantity > target.quantity THEN
  UPDATE SET target.quantity = source.quantity;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 8. Perform merge but ignore cancelled orders.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING (SELECT * FROM incoming_orders WHERE order_status <> 'Cancelled') AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET *
WHEN NOT MATCHED THEN
  INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 9. Create merge that inserts only Laptop products.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET *
WHEN NOT MATCHED AND source.product = 'Laptop' THEN
  INSERT *;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>5</td><td>5</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# 10. Perform merge and update price if new price is higher.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING incoming_orders AS source
ON target.order_id = source.order_id
WHEN MATCHED AND source.price > target.price THEN
  UPDATE SET target.price = source.price;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>num_affected_rows</th><th>num_updated_rows</th><th>num_deleted_rows</th><th>num_inserted_rows</th></tr></thead><tbody><tr><td>0</td><td>0</td><td>0</td><td>0</td></tr></tbody></table></div>

# %% [markdown]
# PART 5 — Realistic UPSERT Scenario

# %%
# %sql
CREATE OR REPLACE TEMP VIEW daily_updates AS
SELECT * FROM VALUES
(103,'Rohit Mehta','Mumbai','Headphones',5,2200,'Delivered'),
(106,'Ananya Das','Kolkata','Mobile',2,28000,'Shipped'),
(112,'Sanjay Gupta','Delhi','Tablet',1,24000,'Placed')
AS daily_updates(order_id,customer_name,city,product,quantity,price,order_status);
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# Exercises
#
# 1. Merge daily_updates into ecommerce_orders.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING daily_updates AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET *
WHEN NOT MATCHED THEN
  INSERT *;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# 2. Update quantity for existing orders.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING daily_updates AS source
ON target.order_id = source.order_id
WHEN MATCHED THEN
  UPDATE SET target.quantity = source.quantity;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# 3. Insert orders that do not exist.

# %%
# %sql
MERGE INTO ecommerce_orders AS target
USING daily_updates AS source
ON target.order_id = source.order_id
WHEN NOT MATCHED THEN
  INSERT *;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# 4. Count how many rows were updated.

# %%
# %sql
DESCRIBE HISTORY ecommerce_orders;

# %%
# %sql
SELECT operationMetrics.num_updated_rows FROM (DESCRIBE HISTORY ecommerce_orders LIMIT 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# 5. Count how many rows were inserted.

# %%
# %sql
SELECT operationMetrics.num_inserted_rows FROM (DESCRIBE HISTORY ecommerce_orders LIMIT 1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %% [markdown]
# 6. Show final table sorted by price descending.

# %%
# %sql
SELECT * 
FROM ecommerce_orders 
ORDER BY price DESC;
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
