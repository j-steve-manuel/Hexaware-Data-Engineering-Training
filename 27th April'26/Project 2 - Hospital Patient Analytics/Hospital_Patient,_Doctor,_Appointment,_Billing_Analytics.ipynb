# %% [markdown]
# Step 1 — Create Data in Google Colab

# %%
patients_csv = """patient_id,name,city,age,gender,registration_date
1,Aarav,Hyderabad,29,Male,2023-01-10
2,Priya,Bangalore,34,Female,2023-02-12
3,Rahul,Mumbai,41,Male,2023-03-14
4,Sneha,Delhi,26,Female,2023-04-15
5,Kiran,Chennai,37,Male,2023-05-11
6,Meera,Hyderabad,31,Female,2023-06-10
7,Amit,Pune,45,Male,2023-06-22
8,Neha,Delhi,28,Female,2023-07-10
9,Divya,Bangalore,33,Female,2023-07-15
10,Vikram,Mumbai,52,Male,2023-08-01
11,Farhan,Hyderabad,39,Male,2023-08-10
12,Simran,Delhi,25,Female,2023-08-21
"""

# %%
doctors_csv = """doctor_id,doctor_name,specialization,city,consultation_fee
101,Dr Sharma,Cardiology,Hyderabad,1200
102,Dr Iyer,Dermatology,Bangalore,800
103,Dr Khan,Orthopedics,Mumbai,1500
104,Dr Reddy,Pediatrics,Delhi,900
105,Dr Mehta,Neurology,Hyderabad,2000
106,Dr Nair,Cardiology,Chennai,1300
107,Dr Verma,Dermatology,Pune,850
108,Dr Rao,Orthopedics,Delhi,1400
"""

# %%
appointments_csv = """appointment_id,patient_id,doctor_id,appointment_date,status
1,1,101,2024-03-01,Completed
2,2,102,2024-03-01,Completed
3,3,103,2024-03-02,Completed
4,4,104,2024-03-02,Pending
5,5,106,2024-03-03,Completed
6,6,105,2024-03-03,Completed
7,7,107,2024-03-04,Cancelled
8,8,108,2024-03-04,Completed
9,9,102,2024-03-05,Completed
10,10,103,2024-03-05,Completed
11,11,101,2024-03-06,Pending
12,12,104,2024-03-06,Completed
13,1,105,2024-03-07,Completed
14,3,108,2024-03-07,Completed
15,6,101,2024-03-08,Cancelled
16,9,106,2024-03-08,Completed
"""

# %%
bills_csv = """bill_id,appointment_id,bill_amount,payment_mode,payment_status
1,1,1200,UPI,Paid
2,2,800,Credit Card,Paid
3,3,1500,Cash,Paid
4,4,900,UPI,Pending
5,5,1300,Debit Card,Paid
6,6,2000,Credit Card,Paid
7,7,850,Cash,Cancelled
8,8,1400,UPI,Paid
9,9,800,UPI,Paid
10,10,1500,Credit Card,Paid
11,11,1200,UPI,Pending
12,12,900,Cash,Paid
13,13,2000,Credit Card,Paid
14,14,1400,UPI,Paid
15,15,1200,Cash,Cancelled
16,16,1300,Debit Card,Paid
"""

# %%
hospital_logs_txt = """Aarav login
Priya login
Rahul appointment
Sneha login
Aarav payment
Kiran appointment
Meera login
Vikram appointment
Divya payment
Farhan login
Simran appointment
Neha payment
Amit login
Rahul payment
Meera appointment
Aarav logout
Priya payment
Divya login
Vikram payment
Farhan appointment
"""

# %%
patient_profiles_json = """[
{
"patient_id": 1,
"name": "Aarav",
"contact": {"email": "aarav@mail.com", "phone": "9000011111"},
"allergies": ["Dust", "Peanuts"]
},
{
"patient_id": 2,
"name": "Priya",
"contact": {"email": "priya@mail.com", "phone": "9000022222"},
"allergies": ["Pollen"]
},
{
"patient_id": 3,
"name": "Rahul",
"contact": {"email": "rahul@mail.com", "phone": "9000033333"},
"allergies": ["Dust", "Milk"]
},
{
"patient_id": 6,
"name": "Meera",
"contact": {"email": "meera@mail.com", "phone": "9000066666"},
"allergies": ["Seafood"]
},
{
"patient_id": 10,
"name": "Vikram",
"contact": {"email": "vikram@mail.com", "phone": "9000101010"},
"allergies": ["Pollen", "Dust"]
}
]
"""

# %%
with open("patients.csv", "w") as f:
  f.write(patients_csv)
with open("doctors.csv", "w") as f:
  f.write(doctors_csv)
with open("appointments.csv", "w") as f:
  f.write(appointments_csv)
with open("bills.csv", "w") as f:
  f.write(bills_csv)
with open("hospital_logs.txt", "w") as f:
  f.write(hospital_logs_txt)
with open("patient_profiles.json", "w") as f:
  f.write(patient_profiles_json)
print("Hospital datasets created successfully")
# Out:
# Hospital datasets created successfully

# %% [markdown]
# Step 2 — Load Data

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("Hospital").getOrCreate()

# %%
patients = spark.read.csv("patients.csv", header=True, inferSchema=True)
doctors = spark.read.csv("doctors.csv", header=True, inferSchema=True)
appointments = spark.read.csv("appointments.csv", header=True, inferSchema = True)
bills = spark.read.csv("bills.csv", header=True, inferSchema=True)
profiles = spark.read.json("patient_profiles.json", multiLine=True)

# %% [markdown]
# 100 PySpark Exercises
# Section 1 — DataFrame Basics
# 1. Show all patients.

# %%
patients.show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 2. Show all doctors.

# %%
doctors.show()
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|
# +---------+-----------+--------------+---------+----------------+

# %% [markdown]
# 3. Show all appointments.

# %%
appointments.show()
# Out:
# +--------------+----------+---------+----------------+---------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|
# +--------------+----------+---------+----------------+---------+
# |             1|         1|      101|      2024-03-01|Completed|
# |             2|         2|      102|      2024-03-01|Completed|
# |             3|         3|      103|      2024-03-02|Completed|
# |             4|         4|      104|      2024-03-02|  Pending|
# |             5|         5|      106|      2024-03-03|Completed|
# |             6|         6|      105|      2024-03-03|Completed|
# |             7|         7|      107|      2024-03-04|Cancelled|
# |             8|         8|      108|      2024-03-04|Completed|
# |             9|         9|      102|      2024-03-05|Completed|
# |            10|        10|      103|      2024-03-05|Completed|
# |            11|        11|      101|      2024-03-06|  Pending|
# |            12|        12|      104|      2024-03-06|Completed|
# |            13|         1|      105|      2024-03-07|Completed|
# |            14|         3|      108|      2024-03-07|Completed|
# |            15|         6|      101|      2024-03-08|Cancelled|
# |            16|         9|      106|      2024-03-08|Completed|
# +--------------+----------+---------+----------------+---------+

# %% [markdown]
# 4. Show all bills.

# %%
bills.show()
# Out:
# +-------+--------------+-----------+------------+--------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|
# +-------+--------------+-----------+------------+--------------+
# |      1|             1|       1200|         UPI|          Paid|
# |      2|             2|        800| Credit Card|          Paid|
# |      3|             3|       1500|        Cash|          Paid|
# |      4|             4|        900|         UPI|       Pending|
# |      5|             5|       1300|  Debit Card|          Paid|
# |      6|             6|       2000| Credit Card|          Paid|
# |      7|             7|        850|        Cash|     Cancelled|
# |      8|             8|       1400|         UPI|          Paid|
# |      9|             9|        800|         UPI|          Paid|
# |     10|            10|       1500| Credit Card|          Paid|
# |     11|            11|       1200|         UPI|       Pending|
# |     12|            12|        900|        Cash|          Paid|
# |     13|            13|       2000| Credit Card|          Paid|
# |     14|            14|       1400|         UPI|          Paid|
# |     15|            15|       1200|        Cash|     Cancelled|
# |     16|            16|       1300|  Debit Card|          Paid|
# +-------+--------------+-----------+------------+--------------+

# %% [markdown]
# 5. Print schema of patients.

# %%
patients.printSchema()
# Out:
# root
#  |-- patient_id: integer (nullable = true)
#  |-- name: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- registration_date: date (nullable = true)

# %% [markdown]
# 6. Print schema of doctors.

# %%
doctors.printSchema()
# Out:
# root
#  |-- doctor_id: integer (nullable = true)
#  |-- doctor_name: string (nullable = true)
#  |-- specialization: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- consultation_fee: integer (nullable = true)

# %% [markdown]
# 7. Print schema of appointments.

# %%
appointments.printSchema()
# Out:
# root
#  |-- appointment_id: integer (nullable = true)
#  |-- patient_id: integer (nullable = true)
#  |-- doctor_id: integer (nullable = true)
#  |-- appointment_date: date (nullable = true)
#  |-- status: string (nullable = true)

# %% [markdown]
# 8. Count total patients.

# %%
patients.count()
# Out:
# 12

# %% [markdown]
# 9. Count total doctors.

# %%
doctors.count()
# Out:
# 8

# %% [markdown]
# 10. Show first 5 appointments.

# %%
appointments.show(5)
# Out:
# +--------------+----------+---------+----------------+---------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|
# +--------------+----------+---------+----------------+---------+
# |             1|         1|      101|      2024-03-01|Completed|
# |             2|         2|      102|      2024-03-01|Completed|
# |             3|         3|      103|      2024-03-02|Completed|
# |             4|         4|      104|      2024-03-02|  Pending|
# |             5|         5|      106|      2024-03-03|Completed|
# +--------------+----------+---------+----------------+---------+
# only showing top 5 rows

# %% [markdown]
# Section 2 — Select, Rename, Filter
#
# 11. Select patient name, city, and age.

# %%
patients.select("name", "city", "age").show()
# Out:
# +------+---------+---+
# |  name|     city|age|
# +------+---------+---+
# | Aarav|Hyderabad| 29|
# | Priya|Bangalore| 34|
# | Rahul|   Mumbai| 41|
# | Sneha|    Delhi| 26|
# | Kiran|  Chennai| 37|
# | Meera|Hyderabad| 31|
# |  Amit|     Pune| 45|
# |  Neha|    Delhi| 28|
# | Divya|Bangalore| 33|
# |Vikram|   Mumbai| 52|
# |Farhan|Hyderabad| 39|
# |Simran|    Delhi| 25|
# +------+---------+---+

# %% [markdown]
# 12. Select doctor name, specialization, and consultation fee.

# %%
doctors.select("doctor_name", "specialization", "consultation_fee").show()
# Out:
# +-----------+--------------+----------------+
# |doctor_name|specialization|consultation_fee|
# +-----------+--------------+----------------+
# |  Dr Sharma|    Cardiology|            1200|
# |    Dr Iyer|   Dermatology|             800|
# |    Dr Khan|   Orthopedics|            1500|
# |   Dr Reddy|    Pediatrics|             900|
# |   Dr Mehta|     Neurology|            2000|
# |    Dr Nair|    Cardiology|            1300|
# |   Dr Verma|   Dermatology|             850|
# |     Dr Rao|   Orthopedics|            1400|
# +-----------+--------------+----------------+

# %% [markdown]
# 13. Rename name in patients to patient_name .

# %%
patients.withColumnRenamed("name", "patient_name").show()
# Out:
# +----------+------------+---------+---+------+-----------------+
# |patient_id|patient_name|     city|age|gender|registration_date|
# +----------+------------+---------+---+------+-----------------+
# |         1|       Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         2|       Priya|Bangalore| 34|Female|       2023-02-12|
# |         3|       Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |         4|       Sneha|    Delhi| 26|Female|       2023-04-15|
# |         5|       Kiran|  Chennai| 37|  Male|       2023-05-11|
# |         6|       Meera|Hyderabad| 31|Female|       2023-06-10|
# |         7|        Amit|     Pune| 45|  Male|       2023-06-22|
# |         8|        Neha|    Delhi| 28|Female|       2023-07-10|
# |         9|       Divya|Bangalore| 33|Female|       2023-07-15|
# |        10|      Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |        11|      Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |        12|      Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------------+---------+---+------+-----------------+

# %% [markdown]
# 14. Rename doctor_name to consultant_name .

# %%
doctors.withColumnRenamed("doctor_name", "consultant_name").show()
# Out:
# +---------+---------------+--------------+---------+----------------+
# |doctor_id|consultant_name|specialization|     city|consultation_fee|
# +---------+---------------+--------------+---------+----------------+
# |      101|      Dr Sharma|    Cardiology|Hyderabad|            1200|
# |      102|        Dr Iyer|   Dermatology|Bangalore|             800|
# |      103|        Dr Khan|   Orthopedics|   Mumbai|            1500|
# |      104|       Dr Reddy|    Pediatrics|    Delhi|             900|
# |      105|       Dr Mehta|     Neurology|Hyderabad|            2000|
# |      106|        Dr Nair|    Cardiology|  Chennai|            1300|
# |      107|       Dr Verma|   Dermatology|     Pune|             850|
# |      108|         Dr Rao|   Orthopedics|    Delhi|            1400|
# +---------+---------------+--------------+---------+----------------+

# %% [markdown]
# 15. Show patients from Hyderabad.

# %%
patients.filter(patients.city == "Hyderabad").show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 16. Show female patients.

# %%
patients.filter(patients.gender == "Female").show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 17. Show patients older than 35.

# %%
patients.filter(patients.age > 35).show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 18. Show doctors from Hyderabad.

# %%
doctors.filter(doctors.city == "Hyderabad").show()
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|
# +---------+-----------+--------------+---------+----------------+

# %% [markdown]
# 19. Show Cardiology doctors.

# %%
doctors.filter(doctors.specialization == "Cardiology").show()
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|
# +---------+-----------+--------------+---------+----------------+

# %% [markdown]
# 20. Show doctors whose fee is greater than 1000.

# %%
doctors.filter(doctors.consultation_fee > 1000).show()
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|
# +---------+-----------+--------------+---------+----------------+

# %% [markdown]
# Section 3 — Sorting and Limit
#
# 21. Sort patients by age ascending.

# %%
patients.sort("age").show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 22. Sort patients by age descending.

# %%
patients.sort(patients.age.desc()).show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 23. Show top 5 oldest patients.

# %%
patients.sort(patients.age.desc()).show(5)
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# +----------+------+---------+---+------+-----------------+
# only showing top 5 rows

# %% [markdown]
# 24. Show youngest 3 patients.

# %%
patients.sort(patients.age).limit(3).show()
# Out:
# +----------+------+-----+---+------+-----------------+
# |patient_id|  name| city|age|gender|registration_date|
# +----------+------+-----+---+------+-----------------+
# |        12|Simran|Delhi| 25|Female|       2023-08-21|
# |         4| Sneha|Delhi| 26|Female|       2023-04-15|
# |         8|  Neha|Delhi| 28|Female|       2023-07-10|
# +----------+------+-----+---+------+-----------------+

# %% [markdown]
# 25. Sort doctors by consultation fee descending.

# %%
doctors.sort(doctors.consultation_fee.desc()).show()
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|
# +---------+-----------+--------------+---------+----------------+

# %% [markdown]
# 26. Show top 3 highest fee doctors.

# %%
doctors.sort(doctors.consultation_fee.desc()).limit(3).show()
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|
# +---------+-----------+--------------+---------+----------------+

# %%
doctors.sort("consultation_fee", ascending = False).show(3)
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|
# +---------+-----------+--------------+---------+----------------+
# only showing top 3 rows

# %% [markdown]
# 27. Show lowest fee doctors.

# %%
doctors.sort("consultation_fee").show(1)
# Out:
# +---------+-----------+--------------+---------+----------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|
# +---------+-----------+--------------+---------+----------------+
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|
# +---------+-----------+--------------+---------+----------------+
# only showing top 1 row

# %% [markdown]
# 28. Sort appointments by appointment date.

# %%
appointments.sort("appointment_date").show()
# Out:
# +--------------+----------+---------+----------------+---------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|
# +--------------+----------+---------+----------------+---------+
# |             1|         1|      101|      2024-03-01|Completed|
# |             2|         2|      102|      2024-03-01|Completed|
# |             3|         3|      103|      2024-03-02|Completed|
# |             4|         4|      104|      2024-03-02|  Pending|
# |             5|         5|      106|      2024-03-03|Completed|
# |             6|         6|      105|      2024-03-03|Completed|
# |             7|         7|      107|      2024-03-04|Cancelled|
# |             8|         8|      108|      2024-03-04|Completed|
# |             9|         9|      102|      2024-03-05|Completed|
# |            10|        10|      103|      2024-03-05|Completed|
# |            11|        11|      101|      2024-03-06|  Pending|
# |            12|        12|      104|      2024-03-06|Completed|
# |            13|         1|      105|      2024-03-07|Completed|
# |            14|         3|      108|      2024-03-07|Completed|
# |            15|         6|      101|      2024-03-08|Cancelled|
# |            16|         9|      106|      2024-03-08|Completed|
# +--------------+----------+---------+----------------+---------+

# %% [markdown]
# 29. Sort bills by bill amount descending.

# %%
bills.sort(bills.bill_amount.desc()).show()
# Out:
# +-------+--------------+-----------+------------+--------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|
# +-------+--------------+-----------+------------+--------------+
# |      6|             6|       2000| Credit Card|          Paid|
# |     13|            13|       2000| Credit Card|          Paid|
# |      3|             3|       1500|        Cash|          Paid|
# |     10|            10|       1500| Credit Card|          Paid|
# |      8|             8|       1400|         UPI|          Paid|
# |     14|            14|       1400|         UPI|          Paid|
# |      5|             5|       1300|  Debit Card|          Paid|
# |     16|            16|       1300|  Debit Card|          Paid|
# |      1|             1|       1200|         UPI|          Paid|
# |     11|            11|       1200|         UPI|       Pending|
# |     15|            15|       1200|        Cash|     Cancelled|
# |      4|             4|        900|         UPI|       Pending|
# |     12|            12|        900|        Cash|          Paid|
# |      7|             7|        850|        Cash|     Cancelled|
# |      2|             2|        800| Credit Card|          Paid|
# |      9|             9|        800|         UPI|          Paid|
# +-------+--------------+-----------+------------+--------------+

# %% [markdown]
# 30. Show top 5 highest bills.

# %%
bills.sort(bills.bill_amount.desc()).limit(5).show()
# Out:
# +-------+--------------+-----------+------------+--------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|
# +-------+--------------+-----------+------------+--------------+
# |      6|             6|       2000| Credit Card|          Paid|
# |     13|            13|       2000| Credit Card|          Paid|
# |      3|             3|       1500|        Cash|          Paid|
# |     10|            10|       1500| Credit Card|          Paid|
# |      8|             8|       1400|         UPI|          Paid|
# +-------+--------------+-----------+------------+--------------+

# %% [markdown]
# Section 4 — Aggregations
#
# 31. Count patients by city.

# %%
patients.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |     Pune|    1|
# |    Delhi|    3|
# |Hyderabad|    3|
# +---------+-----+

# %% [markdown]
# 32. Count patients by gender.

# %%
patients.groupBy("gender").count().show()
# Out:
# +------+-----+
# |gender|count|
# +------+-----+
# |Female|    6|
# |  Male|    6|
# +------+-----+

# %% [markdown]
# 33. Count doctors by specialization.

# %%
doctors.groupBy("specialization").count().show()
# Out:
# +--------------+-----+
# |specialization|count|
# +--------------+-----+
# |     Neurology|    1|
# |   Dermatology|    2|
# |    Cardiology|    2|
# |    Pediatrics|    1|
# |   Orthopedics|    2|
# +--------------+-----+

# %% [markdown]
# 34. Find average patient age.

# %%
patients.agg({"age": "avg"}).show()
# Out:
# +--------+
# |avg(age)|
# +--------+
# |    35.0|
# +--------+

# %% [markdown]
# 35. Find maximum patient age.

# %%
patients.agg({"age": "max"}).show()
# Out:
# +--------+
# |max(age)|
# +--------+
# |      52|
# +--------+

# %% [markdown]
# 36. Find minimum patient age.

# %%
patients.agg({"age": "min"}).show()
# Out:
# +--------+
# |min(age)|
# +--------+
# |      25|
# +--------+

# %% [markdown]
# 37. Find average consultation fee.

# %%
doctors.agg({"consultation_fee": "avg"}).show()
# Out:
# +---------------------+
# |avg(consultation_fee)|
# +---------------------+
# |              1243.75|
# +---------------------+

# %% [markdown]
# 38. Find maximum consultation fee.

# %%
doctors.agg({"consultation_fee": "max"}).show()
# Out:
# +---------------------+
# |max(consultation_fee)|
# +---------------------+
# |                 2000|
# +---------------------+

# %%
from pyspark.sql.functions import max, col

doctors.agg(max("consultation_fee")).show()
# Out:
# +---------------------+
# |max(consultation_fee)|
# +---------------------+
# |                 2000|
# +---------------------+

# %% [markdown]
# 39. Find total bill amount.

# %%
bills.agg({"bill_amount": "sum"}).show()
# Out:
# +----------------+
# |sum(bill_amount)|
# +----------------+
# |           20250|
# +----------------+

# %%
from pyspark.sql.functions import sum

bills.agg(sum("bill_amount")).show()
# Out:
# +----------------+
# |sum(bill_amount)|
# +----------------+
# |           20250|
# +----------------+

# %% [markdown]
# 40. Find average bill amount.

# %%
bills.agg({"bill_amount": "avg"}).show()
# Out:
# +----------------+
# |avg(bill_amount)|
# +----------------+
# |        1265.625|
# +----------------+

# %%
from pyspark.sql.functions import avg

bills.agg(avg("bill_amount")).show()
# Out:
# +----------------+
# |avg(bill_amount)|
# +----------------+
# |        1265.625|
# +----------------+

# %% [markdown]
# Section 5 — GroupBy Analytics
#
# 41. Find patient count by city.

# %%
patients.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    2|
# |  Chennai|    1|
# |   Mumbai|    2|
# |     Pune|    1|
# |    Delhi|    3|
# |Hyderabad|    3|
# +---------+-----+

# %% [markdown]
# 42. Find doctor count by city.

# %%
doctors.groupBy("city").count().show()
# Out:
# +---------+-----+
# |     city|count|
# +---------+-----+
# |Bangalore|    1|
# |  Chennai|    1|
# |   Mumbai|    1|
# |     Pune|    1|
# |    Delhi|    2|
# |Hyderabad|    2|
# +---------+-----+

# %% [markdown]
# 43. Find appointment count by status.

# %%
appointments.groupBy("status").count().show()
# Out:
# +---------+-----+
# |   status|count|
# +---------+-----+
# |Completed|   12|
# |Cancelled|    2|
# |  Pending|    2|
# +---------+-----+

# %% [markdown]
# 44. Find bill amount by payment status.

# %%
bills.groupBy("payment_status").agg({"bill_amount": "sum"}).show()
# Out:
# +--------------+----------------+
# |payment_status|sum(bill_amount)|
# +--------------+----------------+
# |     Cancelled|            2050|
# |       Pending|            2100|
# |          Paid|           16100|
# +--------------+----------------+

# %% [markdown]
# 45. Find total revenue by payment mode.

# %%
bills.groupBy("payment_mode").agg(sum("bill_amount")).show()
# Out:
# +------------+----------------+
# |payment_mode|sum(bill_amount)|
# +------------+----------------+
# | Credit Card|            6300|
# |        Cash|            4450|
# |  Debit Card|            2600|
# |         UPI|            6900|
# +------------+----------------+

# %% [markdown]
# 46. Find average bill amount by payment mode.

# %%
bills.groupBy("payment_mode").agg(avg("bill_amount")).show()
# Out:
# +------------+----------------+
# |payment_mode|avg(bill_amount)|
# +------------+----------------+
# | Credit Card|          1575.0|
# |        Cash|          1112.5|
# |  Debit Card|          1300.0|
# |         UPI|          1150.0|
# +------------+----------------+

# %% [markdown]
# 47. Find appointment count by doctor_id.
#
#
# ---

# %%
appointments.groupBy("doctor_id").count().show()
# Out:
# +---------+-----+
# |doctor_id|count|
# +---------+-----+
# |      108|    2|
# |      101|    3|
# |      103|    2|
# |      107|    1|
# |      102|    2|
# |      105|    2|
# |      106|    2|
# |      104|    2|
# +---------+-----+

# %% [markdown]
# 48. Find appointment count by patient_id.

# %%
appointments.groupBy("patient_id").count().show()
# Out:
# +----------+-----+
# |patient_id|count|
# +----------+-----+
# |        12|    1|
# |         1|    2|
# |         6|    2|
# |         3|    2|
# |         5|    1|
# |         9|    2|
# |         4|    1|
# |         8|    1|
# |         7|    1|
# |        10|    1|
# |        11|    1|
# |         2|    1|
# +----------+-----+

# %% [markdown]
# 49. Find total bill amount by appointment_id.

# %%
appointments.join(bills, on = "appointment_id").groupBy("appointment_id").agg(sum("bill_amount")).show()
# Out:
# +--------------+----------------+
# |appointment_id|sum(bill_amount)|
# +--------------+----------------+
# |            12|             900|
# |             1|            1200|
# |            13|            2000|
# |             6|            2000|
# |            16|            1300|
# |             3|            1500|
# |             5|            1300|
# |            15|            1200|
# |             9|             800|
# |             4|             900|
# |             8|            1400|
# |             7|             850|
# |            10|            1500|
# |            11|            1200|
# |            14|            1400|
# |             2|             800|
# +--------------+----------------+

# %% [markdown]
# 50. Find average consultation fee by specialization.

# %%
from pyspark.sql.functions import avg

doctors.groupBy("specialization").agg(avg("consultation_fee")).show()
# Out:
# +--------------+---------------------+
# |specialization|avg(consultation_fee)|
# +--------------+---------------------+
# |     Neurology|               2000.0|
# |   Dermatology|                825.0|
# |    Cardiology|               1250.0|
# |    Pediatrics|                900.0|
# |   Orthopedics|               1450.0|
# +--------------+---------------------+

# %% [markdown]
# Section 6 — Joins
#
# 51. Join patients with appointments using patient_id .

# %%
patients.join(appointments, patients.patient_id == appointments.patient_id).show()
# Out:
# +----------+------+---------+---+------+-----------------+--------------+----------+---------+----------------+---------+
# |patient_id|  name|     city|age|gender|registration_date|appointment_id|patient_id|doctor_id|appointment_date|   status|
# +----------+------+---------+---+------+-----------------+--------------+----------+---------+----------------+---------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|             1|         1|      101|      2024-03-01|Completed|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|             2|         2|      102|      2024-03-01|Completed|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|             3|         3|      103|      2024-03-02|Completed|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|             4|         4|      104|      2024-03-02|  Pending|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|             5|         5|      106|      2024-03-03|Completed|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|             6|         6|      105|      2024-03-03|Completed|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|             7|         7|      107|      2024-03-04|Cancelled|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|             8|         8|      108|      2024-03-04|Completed|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|             9|         9|      102|      2024-03-05|Completed|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|            10|        10|      103|      2024-03-05|Completed|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|            11|        11|      101|      2024-03-06|  Pending|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|            12|        12|      104|      2024-03-06|Completed|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|            13|         1|      105|      2024-03-07|Completed|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|            14|         3|      108|      2024-03-07|Completed|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|            15|         6|      101|      2024-03-08|Cancelled|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|            16|         9|      106|      2024-03-08|Completed|
# +----------+------+---------+---+------+-----------------+--------------+----------+---------+----------------+---------+

# %% [markdown]
# 52. Show patient name, city, appointment date, and status.

# %%
patients.join(appointments, on = "patient_id")\
.select("name", "city", "appointment_date", "status").show()
# Out:
# +------+---------+----------------+---------+
# |  name|     city|appointment_date|   status|
# +------+---------+----------------+---------+
# | Aarav|Hyderabad|      2024-03-01|Completed|
# | Priya|Bangalore|      2024-03-01|Completed|
# | Rahul|   Mumbai|      2024-03-02|Completed|
# | Sneha|    Delhi|      2024-03-02|  Pending|
# | Kiran|  Chennai|      2024-03-03|Completed|
# | Meera|Hyderabad|      2024-03-03|Completed|
# |  Amit|     Pune|      2024-03-04|Cancelled|
# |  Neha|    Delhi|      2024-03-04|Completed|
# | Divya|Bangalore|      2024-03-05|Completed|
# |Vikram|   Mumbai|      2024-03-05|Completed|
# |Farhan|Hyderabad|      2024-03-06|  Pending|
# |Simran|    Delhi|      2024-03-06|Completed|
# | Aarav|Hyderabad|      2024-03-07|Completed|
# | Rahul|   Mumbai|      2024-03-07|Completed|
# | Meera|Hyderabad|      2024-03-08|Cancelled|
# | Divya|Bangalore|      2024-03-08|Completed|
# +------+---------+----------------+---------+

# %% [markdown]
# 53. Join doctors with appointments using doctor_id .

# %%
joined_df = doctors.join(appointments, on = "doctor_id")
joined_df.show()
# Out:
# +---------+-----------+--------------+---------+----------------+--------------+----------+----------------+---------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|appointment_id|patient_id|appointment_date|   status|
# +---------+-----------+--------------+---------+----------------+--------------+----------+----------------+---------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|             1|         1|      2024-03-01|Completed|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|             2|         2|      2024-03-01|Completed|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|             3|         3|      2024-03-02|Completed|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|             4|         4|      2024-03-02|  Pending|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|             5|         5|      2024-03-03|Completed|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|             6|         6|      2024-03-03|Completed|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|             7|         7|      2024-03-04|Cancelled|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|             8|         8|      2024-03-04|Completed|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|             9|         9|      2024-03-05|Completed|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|            10|        10|      2024-03-05|Completed|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|            11|        11|      2024-03-06|  Pending|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|            12|        12|      2024-03-06|Completed|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|            13|         1|      2024-03-07|Completed|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|            14|         3|      2024-03-07|Completed|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|            15|         6|      2024-03-08|Cancelled|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|            16|         9|      2024-03-08|Completed|
# +---------+-----------+--------------+---------+----------------+--------------+----------+----------------+---------+

# %% [markdown]
# 54. Show doctor name, specialization, appointment date, and status.

# %%
joined_df.select("doctor_name", "specialization", "appointment_date", "status").show()
# Out:
# +-----------+--------------+----------------+---------+
# |doctor_name|specialization|appointment_date|   status|
# +-----------+--------------+----------------+---------+
# |  Dr Sharma|    Cardiology|      2024-03-01|Completed|
# |    Dr Iyer|   Dermatology|      2024-03-01|Completed|
# |    Dr Khan|   Orthopedics|      2024-03-02|Completed|
# |   Dr Reddy|    Pediatrics|      2024-03-02|  Pending|
# |    Dr Nair|    Cardiology|      2024-03-03|Completed|
# |   Dr Mehta|     Neurology|      2024-03-03|Completed|
# |   Dr Verma|   Dermatology|      2024-03-04|Cancelled|
# |     Dr Rao|   Orthopedics|      2024-03-04|Completed|
# |    Dr Iyer|   Dermatology|      2024-03-05|Completed|
# |    Dr Khan|   Orthopedics|      2024-03-05|Completed|
# |  Dr Sharma|    Cardiology|      2024-03-06|  Pending|
# |   Dr Reddy|    Pediatrics|      2024-03-06|Completed|
# |   Dr Mehta|     Neurology|      2024-03-07|Completed|
# |     Dr Rao|   Orthopedics|      2024-03-07|Completed|
# |  Dr Sharma|    Cardiology|      2024-03-08|Cancelled|
# |    Dr Nair|    Cardiology|      2024-03-08|Completed|
# +-----------+--------------+----------------+---------+

# %% [markdown]
# 55. Join appointments with bills using appointment_id .

# %%
combined_df = appointments.join(bills, on = "appointment_id")
combined_df.show()
# Out:
# +--------------+----------+---------+----------------+---------+-------+-----------+------------+--------------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|bill_id|bill_amount|payment_mode|payment_status|
# +--------------+----------+---------+----------------+---------+-------+-----------+------------+--------------+
# |             1|         1|      101|      2024-03-01|Completed|      1|       1200|         UPI|          Paid|
# |             2|         2|      102|      2024-03-01|Completed|      2|        800| Credit Card|          Paid|
# |             3|         3|      103|      2024-03-02|Completed|      3|       1500|        Cash|          Paid|
# |             4|         4|      104|      2024-03-02|  Pending|      4|        900|         UPI|       Pending|
# |             5|         5|      106|      2024-03-03|Completed|      5|       1300|  Debit Card|          Paid|
# |             6|         6|      105|      2024-03-03|Completed|      6|       2000| Credit Card|          Paid|
# |             7|         7|      107|      2024-03-04|Cancelled|      7|        850|        Cash|     Cancelled|
# |             8|         8|      108|      2024-03-04|Completed|      8|       1400|         UPI|          Paid|
# |             9|         9|      102|      2024-03-05|Completed|      9|        800|         UPI|          Paid|
# |            10|        10|      103|      2024-03-05|Completed|     10|       1500| Credit Card|          Paid|
# |            11|        11|      101|      2024-03-06|  Pending|     11|       1200|         UPI|       Pending|
# |            12|        12|      104|      2024-03-06|Completed|     12|        900|        Cash|          Paid|
# |            13|         1|      105|      2024-03-07|Completed|     13|       2000| Credit Card|          Paid|
# |            14|         3|      108|      2024-03-07|Completed|     14|       1400|         UPI|          Paid|
# |            15|         6|      101|      2024-03-08|Cancelled|     15|       1200|        Cash|     Cancelled|
# |            16|         9|      106|      2024-03-08|Completed|     16|       1300|  Debit Card|          Paid|
# +--------------+----------+---------+----------------+---------+-------+-----------+------------+--------------+

# %% [markdown]
# 56. Show appointment_id, status, bill amount, and payment status.

# %%
combined_df.select("appointment_id", "status", "bill_amount", "payment_status").show()
# Out:
# +--------------+---------+-----------+--------------+
# |appointment_id|   status|bill_amount|payment_status|
# +--------------+---------+-----------+--------------+
# |             1|Completed|       1200|          Paid|
# |             2|Completed|        800|          Paid|
# |             3|Completed|       1500|          Paid|
# |             4|  Pending|        900|       Pending|
# |             5|Completed|       1300|          Paid|
# |             6|Completed|       2000|          Paid|
# |             7|Cancelled|        850|     Cancelled|
# |             8|Completed|       1400|          Paid|
# |             9|Completed|        800|          Paid|
# |            10|Completed|       1500|          Paid|
# |            11|  Pending|       1200|       Pending|
# |            12|Completed|        900|          Paid|
# |            13|Completed|       2000|          Paid|
# |            14|Completed|       1400|          Paid|
# |            15|Cancelled|       1200|     Cancelled|
# |            16|Completed|       1300|          Paid|
# +--------------+---------+-----------+--------------+

# %% [markdown]
# 57. Join patients, appointments, and doctors.

# %%
joined_df = patients.join(appointments, on = "patient_id")\
.join(doctors, on = "doctor_id")

# %% [markdown]
# 58. Show patient name, doctor name, specialization, and appointment date.

# %%
joined_df.select("name", "doctor_name", "specialization", "appointment_date").show()
# Out:
# +------+-----------+--------------+----------------+
# |  name|doctor_name|specialization|appointment_date|
# +------+-----------+--------------+----------------+
# | Aarav|  Dr Sharma|    Cardiology|      2024-03-01|
# | Priya|    Dr Iyer|   Dermatology|      2024-03-01|
# | Rahul|    Dr Khan|   Orthopedics|      2024-03-02|
# | Sneha|   Dr Reddy|    Pediatrics|      2024-03-02|
# | Kiran|    Dr Nair|    Cardiology|      2024-03-03|
# | Meera|   Dr Mehta|     Neurology|      2024-03-03|
# |  Amit|   Dr Verma|   Dermatology|      2024-03-04|
# |  Neha|     Dr Rao|   Orthopedics|      2024-03-04|
# | Divya|    Dr Iyer|   Dermatology|      2024-03-05|
# |Vikram|    Dr Khan|   Orthopedics|      2024-03-05|
# |Farhan|  Dr Sharma|    Cardiology|      2024-03-06|
# |Simran|   Dr Reddy|    Pediatrics|      2024-03-06|
# | Aarav|   Dr Mehta|     Neurology|      2024-03-07|
# | Rahul|     Dr Rao|   Orthopedics|      2024-03-07|
# | Meera|  Dr Sharma|    Cardiology|      2024-03-08|
# | Divya|    Dr Nair|    Cardiology|      2024-03-08|
# +------+-----------+--------------+----------------+

# %% [markdown]
# 59. Join patients, appointments, doctors, and bills.

# %%
joined_df = patients.join(appointments, on = "patient_id")\
.join(doctors, on = "doctor_id")

# %% [markdown]
# 60. Show patient name, doctor name, status, bill amount, and payment mode.

# %%
joined_df.join(bills, on = "appointment_id").select("name", "doctor_name", "status", "bill_amount", "payment_mode").show()
# Out:
# +------+-----------+---------+-----------+------------+
# |  name|doctor_name|   status|bill_amount|payment_mode|
# +------+-----------+---------+-----------+------------+
# | Aarav|  Dr Sharma|Completed|       1200|         UPI|
# | Priya|    Dr Iyer|Completed|        800| Credit Card|
# | Rahul|    Dr Khan|Completed|       1500|        Cash|
# | Sneha|   Dr Reddy|  Pending|        900|         UPI|
# | Kiran|    Dr Nair|Completed|       1300|  Debit Card|
# | Meera|   Dr Mehta|Completed|       2000| Credit Card|
# |  Amit|   Dr Verma|Cancelled|        850|        Cash|
# |  Neha|     Dr Rao|Completed|       1400|         UPI|
# | Divya|    Dr Iyer|Completed|        800|         UPI|
# |Vikram|    Dr Khan|Completed|       1500| Credit Card|
# |Farhan|  Dr Sharma|  Pending|       1200|         UPI|
# |Simran|   Dr Reddy|Completed|        900|        Cash|
# | Aarav|   Dr Mehta|Completed|       2000| Credit Card|
# | Rahul|     Dr Rao|Completed|       1400|         UPI|
# | Meera|  Dr Sharma|Cancelled|       1200|        Cash|
# | Divya|    Dr Nair|Completed|       1300|  Debit Card|
# +------+-----------+---------+-----------+------------+

# %% [markdown]
# Section 7 — Updating Data with withColumn
#
# 61. Add age_group column using age.

# %%
from pyspark.sql.functions import when, col

patients.withColumn("age_group", when(col("age") < 18, "Minor")\
.when((col("age") >= 18) & (col("age") < 40), "Youth")\
.otherwise("Adult")).show()
# Out:
# +----------+------+---------+---+------+-----------------+---------+
# |patient_id|  name|     city|age|gender|registration_date|age_group|
# +----------+------+---------+---+------+-----------------+---------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|    Youth|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|    Youth|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|    Adult|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|    Youth|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|    Youth|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|    Youth|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|    Adult|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|    Youth|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|    Youth|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|    Adult|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|    Youth|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|    Youth|
# +----------+------+---------+---+------+-----------------+---------+

# %% [markdown]
# 62. Add hospital_name = "BotCampus Hospital" .

# %%
from pyspark.sql.functions import lit

patients.withColumn("hospital_name", lit("BotCampus Hospital")).show()
# Out:
# +----------+------+---------+---+------+-----------------+------------------+
# |patient_id|  name|     city|age|gender|registration_date|     hospital_name|
# +----------+------+---------+---+------+-----------------+------------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|BotCampus Hospital|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|BotCampus Hospital|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|BotCampus Hospital|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|BotCampus Hospital|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|BotCampus Hospital|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|BotCampus Hospital|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|BotCampus Hospital|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|BotCampus Hospital|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|BotCampus Hospital|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|BotCampus Hospital|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|BotCampus Hospital|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|BotCampus Hospital|
# +----------+------+---------+---+------+-----------------+------------------+

# %% [markdown]
# 63. Add fee_with_tax = consultation_fee * 1.18 .

# %%
doctors.withColumn("fee_with_tax", col("consultation_fee") * 1.18).show()
# Out:
# +---------+-----------+--------------+---------+----------------+------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|fee_with_tax|
# +---------+-----------+--------------+---------+----------------+------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|      1416.0|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|       944.0|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|      1770.0|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|      1062.0|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|      2360.0|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|      1534.0|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|      1003.0|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|      1652.0|
# +---------+-----------+--------------+---------+----------------+------------+

# %% [markdown]
# 64. Add bill_with_tax = bill_amount * 1.18 .

# %%
bills.withColumn("bill_with_tax", col("bill_amount") * 1.18).show()
# Out:
# +-------+--------------+-----------+------------+--------------+-------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|bill_with_tax|
# +-------+--------------+-----------+------------+--------------+-------------+
# |      1|             1|       1200|         UPI|          Paid|       1416.0|
# |      2|             2|        800| Credit Card|          Paid|        944.0|
# |      3|             3|       1500|        Cash|          Paid|       1770.0|
# |      4|             4|        900|         UPI|       Pending|       1062.0|
# |      5|             5|       1300|  Debit Card|          Paid|       1534.0|
# |      6|             6|       2000| Credit Card|          Paid|       2360.0|
# |      7|             7|        850|        Cash|     Cancelled|       1003.0|
# |      8|             8|       1400|         UPI|          Paid|       1652.0|
# |      9|             9|        800|         UPI|          Paid|        944.0|
# |     10|            10|       1500| Credit Card|          Paid|       1770.0|
# |     11|            11|       1200|         UPI|       Pending|       1416.0|
# |     12|            12|        900|        Cash|          Paid|       1062.0|
# |     13|            13|       2000| Credit Card|          Paid|       2360.0|
# |     14|            14|       1400|         UPI|          Paid|       1652.0|
# |     15|            15|       1200|        Cash|     Cancelled|       1416.0|
# |     16|            16|       1300|  Debit Card|          Paid|       1534.0|
# +-------+--------------+-----------+------------+--------------+-------------+

# %% [markdown]
# 65. Add bill_in_thousands = bill_amount / 1000 .

# %%
bills.withColumn("bill_in_thousands", col("bill_amount") / 1000).show()
# Out:
# +-------+--------------+-----------+------------+--------------+-----------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|bill_in_thousands|
# +-------+--------------+-----------+------------+--------------+-----------------+
# |      1|             1|       1200|         UPI|          Paid|              1.2|
# |      2|             2|        800| Credit Card|          Paid|              0.8|
# |      3|             3|       1500|        Cash|          Paid|              1.5|
# |      4|             4|        900|         UPI|       Pending|              0.9|
# |      5|             5|       1300|  Debit Card|          Paid|              1.3|
# |      6|             6|       2000| Credit Card|          Paid|              2.0|
# |      7|             7|        850|        Cash|     Cancelled|             0.85|
# |      8|             8|       1400|         UPI|          Paid|              1.4|
# |      9|             9|        800|         UPI|          Paid|              0.8|
# |     10|            10|       1500| Credit Card|          Paid|              1.5|
# |     11|            11|       1200|         UPI|       Pending|              1.2|
# |     12|            12|        900|        Cash|          Paid|              0.9|
# |     13|            13|       2000| Credit Card|          Paid|              2.0|
# |     14|            14|       1400|         UPI|          Paid|              1.4|
# |     15|            15|       1200|        Cash|     Cancelled|              1.2|
# |     16|            16|       1300|  Debit Card|          Paid|              1.3|
# +-------+--------------+-----------+------------+--------------+-----------------+

# %% [markdown]
# 66. Add country = "India" to patients.

# %%
patients.withColumn("country", lit("India")).show()
# Out:
# +----------+------+---------+---+------+-----------------+-------+
# |patient_id|  name|     city|age|gender|registration_date|country|
# +----------+------+---------+---+------+-----------------+-------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|  India|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|  India|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|  India|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|  India|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|  India|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|  India|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|  India|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|  India|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|  India|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|  India|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|  India|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|  India|
# +----------+------+---------+---+------+-----------------+-------+

# %% [markdown]
# 67. Add doctor_label = doctor_name + " - " + specialization .

# %%
from pyspark.sql.functions import lit, concat

doctors.withColumn(
    "doctor_label",
    concat(col("doctor_name"), lit(" - "), col("specialization"))
).show()
# Out:
# +---------+-----------+--------------+---------+----------------+--------------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|        doctor_label|
# +---------+-----------+--------------+---------+----------------+--------------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|Dr Sharma - Cardi...|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|Dr Iyer - Dermato...|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|Dr Khan - Orthope...|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|Dr Reddy - Pediat...|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|Dr Mehta - Neurology|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|Dr Nair - Cardiology|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|Dr Verma - Dermat...|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|Dr Rao - Orthopedics|
# +---------+-----------+--------------+---------+----------------+--------------------+

# %% [markdown]
# 68. Add patient_label = name + " - " + city .

# %%
patients.withColumn(
    "patient_label",
    concat(col("name"), lit(" - "), col("city")))\
    .show()
# Out:
# +----------+------+---------+---+------+-----------------+------------------+
# |patient_id|  name|     city|age|gender|registration_date|     patient_label|
# +----------+------+---------+---+------+-----------------+------------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10| Aarav - Hyderabad|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12| Priya - Bangalore|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|    Rahul - Mumbai|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|     Sneha - Delhi|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|   Kiran - Chennai|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10| Meera - Hyderabad|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|       Amit - Pune|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|      Neha - Delhi|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15| Divya - Bangalore|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|   Vikram - Mumbai|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|Farhan - Hyderabad|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|    Simran - Delhi|
# +----------+------+---------+---+------+-----------------+------------------+

# %% [markdown]
# 69. Add high_bill_flag where bill amount is above 1500.

# %%
bills.withColumn("high_bill_flag", when(col("bill_amount") > 1500, 1).otherwise(0)).show()
# Out:
# +-------+--------------+-----------+------------+--------------+--------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|high_bill_flag|
# +-------+--------------+-----------+------------+--------------+--------------+
# |      1|             1|       1200|         UPI|          Paid|             0|
# |      2|             2|        800| Credit Card|          Paid|             0|
# |      3|             3|       1500|        Cash|          Paid|             0|
# |      4|             4|        900|         UPI|       Pending|             0|
# |      5|             5|       1300|  Debit Card|          Paid|             0|
# |      6|             6|       2000| Credit Card|          Paid|             1|
# |      7|             7|        850|        Cash|     Cancelled|             0|
# |      8|             8|       1400|         UPI|          Paid|             0|
# |      9|             9|        800|         UPI|          Paid|             0|
# |     10|            10|       1500| Credit Card|          Paid|             0|
# |     11|            11|       1200|         UPI|       Pending|             0|
# |     12|            12|        900|        Cash|          Paid|             0|
# |     13|            13|       2000| Credit Card|          Paid|             1|
# |     14|            14|       1400|         UPI|          Paid|             0|
# |     15|            15|       1200|        Cash|     Cancelled|             0|
# |     16|            16|       1300|  Debit Card|          Paid|             0|
# +-------+--------------+-----------+------------+--------------+--------------+

# %% [markdown]
# 70. Add senior_patient_flag where age is above 40.\

# %%
patients.withColumn("senior_patient_flag", when(col("age") > 40, 1).otherwise(0)).show()
# Out:
# +----------+------+---------+---+------+-----------------+-------------------+
# |patient_id|  name|     city|age|gender|registration_date|senior_patient_flag|
# +----------+------+---------+---+------+-----------------+-------------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|                  0|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|                  0|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|                  1|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|                  0|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|                  0|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|                  0|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|                  1|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|                  0|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|                  0|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|                  1|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|                  0|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|                  0|
# +----------+------+---------+---+------+-----------------+-------------------+

# %% [markdown]
# Section 8 — When / Otherwise
#
# 71. Create patient age category: Young, Adult, Senior.

# %%
from pyspark.sql.functions import col, when

patients.withColumn("age_category",
    when(col("age") < 30, "Young")
    .when(col("age") <= 45, "Adult")
    .otherwise("Senior")
).show()
# Out:
# +----------+------+---------+---+------+-----------------+------------+
# |patient_id|  name|     city|age|gender|registration_date|age_category|
# +----------+------+---------+---+------+-----------------+------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|       Young|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|       Adult|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|       Adult|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|       Young|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|       Adult|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|       Adult|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|       Adult|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|       Young|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|       Adult|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|      Senior|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|       Adult|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|       Young|
# +----------+------+---------+---+------+-----------------+------------+

# %% [markdown]
# 72. Create bill category: High, Medium, Low.

# %%
bills.withColumn("bill_category",
    when(col("bill_amount") > 1500, "High")
    .when(col("bill_amount") > 1000, "Medium")
    .otherwise("Low")
).show()
# Out:
# +-------+--------------+-----------+------------+--------------+-------------+
# |bill_id|appointment_id|bill_amount|payment_mode|payment_status|bill_category|
# +-------+--------------+-----------+------------+--------------+-------------+
# |      1|             1|       1200|         UPI|          Paid|       Medium|
# |      2|             2|        800| Credit Card|          Paid|          Low|
# |      3|             3|       1500|        Cash|          Paid|       Medium|
# |      4|             4|        900|         UPI|       Pending|          Low|
# |      5|             5|       1300|  Debit Card|          Paid|       Medium|
# |      6|             6|       2000| Credit Card|          Paid|         High|
# |      7|             7|        850|        Cash|     Cancelled|          Low|
# |      8|             8|       1400|         UPI|          Paid|       Medium|
# |      9|             9|        800|         UPI|          Paid|          Low|
# |     10|            10|       1500| Credit Card|          Paid|       Medium|
# |     11|            11|       1200|         UPI|       Pending|       Medium|
# |     12|            12|        900|        Cash|          Paid|          Low|
# |     13|            13|       2000| Credit Card|          Paid|         High|
# |     14|            14|       1400|         UPI|          Paid|       Medium|
# |     15|            15|       1200|        Cash|     Cancelled|       Medium|
# |     16|            16|       1300|  Debit Card|          Paid|       Medium|
# +-------+--------------+-----------+------------+--------------+-------------+

# %% [markdown]
# 73. Create doctor fee category: Premium, Standard, Basic.

# %%
doctors.withColumn("fee_category",
    when(col("consultation_fee") > 1000, "Premium")
    .when(col("consultation_fee") >500, "Standard")
    .otherwise("Basic")
).show()
# Out:
# +---------+-----------+--------------+---------+----------------+------------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|fee_category|
# +---------+-----------+--------------+---------+----------------+------------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|     Premium|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|    Standard|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|     Premium|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|    Standard|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|     Premium|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|     Premium|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|    Standard|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|     Premium|
# +---------+-----------+--------------+---------+----------------+------------+

# %% [markdown]
# 74. Create appointment priority: Pending = High, Completed = Normal, Cancelled = Low.

# %%
appointments.withColumn("priority",
    when(col("status") == "Pending", "High")
    .when(col("status") == "Completed", "Normal")
    .otherwise("Low")
).show()
# Out:
# +--------------+----------+---------+----------------+---------+--------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|priority|
# +--------------+----------+---------+----------------+---------+--------+
# |             1|         1|      101|      2024-03-01|Completed|  Normal|
# |             2|         2|      102|      2024-03-01|Completed|  Normal|
# |             3|         3|      103|      2024-03-02|Completed|  Normal|
# |             4|         4|      104|      2024-03-02|  Pending|    High|
# |             5|         5|      106|      2024-03-03|Completed|  Normal|
# |             6|         6|      105|      2024-03-03|Completed|  Normal|
# |             7|         7|      107|      2024-03-04|Cancelled|     Low|
# |             8|         8|      108|      2024-03-04|Completed|  Normal|
# |             9|         9|      102|      2024-03-05|Completed|  Normal|
# |            10|        10|      103|      2024-03-05|Completed|  Normal|
# |            11|        11|      101|      2024-03-06|  Pending|    High|
# |            12|        12|      104|      2024-03-06|Completed|  Normal|
# |            13|         1|      105|      2024-03-07|Completed|  Normal|
# |            14|         3|      108|      2024-03-07|Completed|  Normal|
# |            15|         6|      101|      2024-03-08|Cancelled|     Low|
# |            16|         9|      106|      2024-03-08|Completed|  Normal|
# +--------------+----------+---------+----------------+---------+--------+

# %% [markdown]
# 75. Create city zone: Hyderabad/Bangalore/Chennai = South, Mumbai/Delhi/Pune = Metro.

# %%
patients.withColumn("city_zone",
    when(col("city").isin(["Hyderabad", "Bangalore", "Chennai"]), "South")
    .when(col("city").isin(["Mumbai", "Delhi", "Pune"]), "Metro")
    .otherwise("Other")
).show()
# Out:
# +----------+------+---------+---+------+-----------------+---------+
# |patient_id|  name|     city|age|gender|registration_date|city_zone|
# +----------+------+---------+---+------+-----------------+---------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|    South|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|    South|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|    Metro|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|    Metro|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|    South|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|    South|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|    Metro|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|    Metro|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|    South|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|    Metro|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|    South|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|    Metro|
# +----------+------+---------+---+------+-----------------+---------+

# %% [markdown]
# Section 9 — Date Functions
#
# 76. Convert registration_date to date type.

# %%
patients.withColumn("registration_date", col("registration_date").cast("date")).show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 77. Extract registration year.

# %%
from pyspark.sql.functions import year
patients.withColumn("registration_year", year(col("registration_date"))).show()
# Out:
# +----------+------+---------+---+------+-----------------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|registration_year|
# +----------+------+---------+---+------+-----------------+-----------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|             2023|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|             2023|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|             2023|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|             2023|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|             2023|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|             2023|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|             2023|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|             2023|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|             2023|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|             2023|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|             2023|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|             2023|
# +----------+------+---------+---+------+-----------------+-----------------+

# %% [markdown]
# 78. Extract registration month.

# %%
from pyspark.sql.functions import month

patients.withColumn("registration_month", month(col("registration_date"))).show()
# Out:
# +----------+------+---------+---+------+-----------------+------------------+
# |patient_id|  name|     city|age|gender|registration_date|registration_month|
# +----------+------+---------+---+------+-----------------+------------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|                 1|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|                 2|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|                 3|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|                 4|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|                 5|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|                 6|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|                 6|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|                 7|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|                 7|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|                 8|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|                 8|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|                 8|
# +----------+------+---------+---+------+-----------------+------------------+

# %% [markdown]
# 79. Convert appointment_date to date type.

# %%
appointments.withColumn("appointment_date", col("appointment_date").cast("date")).show()
# Out:
# +--------------+----------+---------+----------------+---------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|
# +--------------+----------+---------+----------------+---------+
# |             1|         1|      101|      2024-03-01|Completed|
# |             2|         2|      102|      2024-03-01|Completed|
# |             3|         3|      103|      2024-03-02|Completed|
# |             4|         4|      104|      2024-03-02|  Pending|
# |             5|         5|      106|      2024-03-03|Completed|
# |             6|         6|      105|      2024-03-03|Completed|
# |             7|         7|      107|      2024-03-04|Cancelled|
# |             8|         8|      108|      2024-03-04|Completed|
# |             9|         9|      102|      2024-03-05|Completed|
# |            10|        10|      103|      2024-03-05|Completed|
# |            11|        11|      101|      2024-03-06|  Pending|
# |            12|        12|      104|      2024-03-06|Completed|
# |            13|         1|      105|      2024-03-07|Completed|
# |            14|         3|      108|      2024-03-07|Completed|
# |            15|         6|      101|      2024-03-08|Cancelled|
# |            16|         9|      106|      2024-03-08|Completed|
# +--------------+----------+---------+----------------+---------+

# %% [markdown]
# 80. Extract appointment month.

# %%
appointments.withColumn("appointment_month", month(col("appointment_date"))).show()
# Out:
# +--------------+----------+---------+----------------+---------+-----------------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|appointment_month|
# +--------------+----------+---------+----------------+---------+-----------------+
# |             1|         1|      101|      2024-03-01|Completed|                3|
# |             2|         2|      102|      2024-03-01|Completed|                3|
# |             3|         3|      103|      2024-03-02|Completed|                3|
# |             4|         4|      104|      2024-03-02|  Pending|                3|
# |             5|         5|      106|      2024-03-03|Completed|                3|
# |             6|         6|      105|      2024-03-03|Completed|                3|
# |             7|         7|      107|      2024-03-04|Cancelled|                3|
# |             8|         8|      108|      2024-03-04|Completed|                3|
# |             9|         9|      102|      2024-03-05|Completed|                3|
# |            10|        10|      103|      2024-03-05|Completed|                3|
# |            11|        11|      101|      2024-03-06|  Pending|                3|
# |            12|        12|      104|      2024-03-06|Completed|                3|
# |            13|         1|      105|      2024-03-07|Completed|                3|
# |            14|         3|      108|      2024-03-07|Completed|                3|
# |            15|         6|      101|      2024-03-08|Cancelled|                3|
# |            16|         9|      106|      2024-03-08|Completed|                3|
# +--------------+----------+---------+----------------+---------+-----------------+

# %% [markdown]
# 81. Count appointments by appointment date.

# %%
appointments.groupBy("appointment_date").count().show()
# Out:
# +----------------+-----+
# |appointment_date|count|
# +----------------+-----+
# |      2024-03-05|    2|
# |      2024-03-06|    2|
# |      2024-03-08|    2|
# |      2024-03-04|    2|
# |      2024-03-02|    2|
# |      2024-03-01|    2|
# |      2024-03-03|    2|
# |      2024-03-07|    2|
# +----------------+-----+

# %% [markdown]
# 82. Count appointments by appointment month.

# %%
appointments.groupBy(month("appointment_date")).count().show()
# Out:
# +-----------------------+-----+
# |month(appointment_date)|count|
# +-----------------------+-----+
# |                      3|   16|
# +-----------------------+-----+

# %% [markdown]
# 83. Find patients registered after 2023-06-01 .

# %%
patients.filter(col("registration_date") > "2023-06-01").show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 84. Find days since patient registration.

# %%
from pyspark.sql.functions import datediff, current_date

patients.withColumn("days_since_registration", \
                    datediff(current_date(), col("registration_date"))).show()
# Out:
# +----------+------+---------+---+------+-----------------+-----------------------+
# |patient_id|  name|     city|age|gender|registration_date|days_since_registration|
# +----------+------+---------+---+------+-----------------+-----------------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|                   1203|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|                   1170|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|                   1140|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|                   1108|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|                   1082|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|                   1052|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|                   1040|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|                   1022|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|                   1017|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|                   1000|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|                    991|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|                    980|
# +----------+------+---------+---+------+-----------------+-----------------------+

# %% [markdown]
# 85. Find days since appointment date.

# %%
appointments.withColumn("days_since_appointment", \
                    datediff(current_date(), col("appointment_date"))).show()
# Out:
# +--------------+----------+---------+----------------+---------+----------------------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|days_since_appointment|
# +--------------+----------+---------+----------------+---------+----------------------+
# |             1|         1|      101|      2024-03-01|Completed|                   787|
# |             2|         2|      102|      2024-03-01|Completed|                   787|
# |             3|         3|      103|      2024-03-02|Completed|                   786|
# |             4|         4|      104|      2024-03-02|  Pending|                   786|
# |             5|         5|      106|      2024-03-03|Completed|                   785|
# |             6|         6|      105|      2024-03-03|Completed|                   785|
# |             7|         7|      107|      2024-03-04|Cancelled|                   784|
# |             8|         8|      108|      2024-03-04|Completed|                   784|
# |             9|         9|      102|      2024-03-05|Completed|                   783|
# |            10|        10|      103|      2024-03-05|Completed|                   783|
# |            11|        11|      101|      2024-03-06|  Pending|                   782|
# |            12|        12|      104|      2024-03-06|Completed|                   782|
# |            13|         1|      105|      2024-03-07|Completed|                   781|
# |            14|         3|      108|      2024-03-07|Completed|                   781|
# |            15|         6|      101|      2024-03-08|Cancelled|                   780|
# |            16|         9|      106|      2024-03-08|Completed|                   780|
# +--------------+----------+---------+----------------+---------+----------------------+

# %% [markdown]
# Section 10 — Window Functions
#
# 86. Rank patients by age within city.

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import rank
from pyspark.sql.functions import col


patients.withColumn("age_rank", rank().over(Window.partitionBy("city").orderBy("age"))).show()
# Out:
# +----------+------+---------+---+------+-----------------+--------+
# |patient_id|  name|     city|age|gender|registration_date|age_rank|
# +----------+------+---------+---+------+-----------------+--------+
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|       1|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|       2|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|       1|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|       1|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|       2|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|       3|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|       1|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|       2|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|       3|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|       1|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|       2|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|       1|
# +----------+------+---------+---+------+-----------------+--------+

# %% [markdown]
# 87. Use row_number to find oldest patient per city.

# %%
from pyspark.sql.functions import row_number

patients.withColumn("row_number", row_number().over(Window.partitionBy("city").orderBy(col("age").desc()))).show()
# Out:
# +----------+------+---------+---+------+-----------------+----------+
# |patient_id|  name|     city|age|gender|registration_date|row_number|
# +----------+------+---------+---+------+-----------------+----------+
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|         1|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|         2|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|         1|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|         1|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|         2|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|         3|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|         1|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|         2|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|         3|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|         1|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|         2|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|         1|
# +----------+------+---------+---+------+-----------------+----------+

# %% [markdown]
# 88. Use dense_rank to rank doctors by fee within specialization.

# %%
from pyspark.sql.functions import dense_rank, desc

doctors.withColumn("fee_rank",
    dense_rank().over(Window.partitionBy("specialization").orderBy(desc("consultation_fee")))
).show()
# Out:
# +---------+-----------+--------------+---------+----------------+--------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|fee_rank|
# +---------+-----------+--------------+---------+----------------+--------+
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|       1|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|       2|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|       1|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|       2|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|       1|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|       1|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|       2|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|       1|
# +---------+-----------+--------------+---------+----------------+--------+

# %% [markdown]
# 89. Find highest fee doctor per specialization.

# %%
from pyspark.sql.functions import max

doctors.withColumn("max_fee", max("consultation_fee").over(Window.partitionBy("specialization"))).show()
# Out:
# +---------+-----------+--------------+---------+----------------+-------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|max_fee|
# +---------+-----------+--------------+---------+----------------+-------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|   1300|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|   1300|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|    850|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|    850|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|   2000|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|   1500|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|   1500|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|    900|
# +---------+-----------+--------------+---------+----------------+-------+

# %% [markdown]
# 90. Find top 2 oldest patients per city.

# %%
patients.withColumn("age_rank", rank()\
                    .over(Window.partitionBy("city")\
                          .orderBy(col("age").desc())\
                          )).show()
# Out:
# +----------+------+---------+---+------+-----------------+--------+
# |patient_id|  name|     city|age|gender|registration_date|age_rank|
# +----------+------+---------+---+------+-----------------+--------+
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|       1|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|       2|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|       1|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|       1|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|       2|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|       3|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|       1|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|       2|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|       3|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|       1|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|       2|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|       1|
# +----------+------+---------+---+------+-----------------+--------+

# %% [markdown]
# 91. Rank doctors by consultation fee overall.

# %%
doctors.withColumn("fee_rank", rank().over(Window.orderBy("consultation_fee"))).show()
# Out:
# +---------+-----------+--------------+---------+----------------+--------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|fee_rank|
# +---------+-----------+--------------+---------+----------------+--------+
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|       1|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|       2|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|       3|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|       4|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|       5|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|       6|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|       7|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|       8|
# +---------+-----------+--------------+---------+----------------+--------+

# %% [markdown]
# 92. Rank cities by patient count.

# %%
patients.groupBy("city").count().withColumn("city_rank", rank().over(Window.orderBy("count"))).show()
# Out:
# +---------+-----+---------+
# |     city|count|city_rank|
# +---------+-----+---------+
# |  Chennai|    1|        1|
# |     Pune|    1|        1|
# |Bangalore|    2|        3|
# |   Mumbai|    2|        3|
# |    Delhi|    3|        5|
# |Hyderabad|    3|        5|
# +---------+-----+---------+

# %% [markdown]
# 93. Rank doctors by appointment count.

# %%
appointments.groupBy("doctor_id").count().withColumn("doctor_rank", rank().over(Window.orderBy("count"))).show()
# Out:
# +---------+-----+-----------+
# |doctor_id|count|doctor_rank|
# +---------+-----+-----------+
# |      107|    1|          1|
# |      108|    2|          2|
# |      103|    2|          2|
# |      102|    2|          2|
# |      105|    2|          2|
# |      106|    2|          2|
# |      104|    2|          2|
# |      101|    3|          8|
# +---------+-----+-----------+

# %% [markdown]
# 94. Create running total bill amount by payment mode.

# %%
window_running = Window.partitionBy("payment_mode").orderBy("bill_id")

bills.withColumn("running_total", sum("bill_amount").over(window_running)) \
     .select("payment_mode", "bill_id", "bill_amount", "running_total") \
     .show()
# Out:
# +------------+-------+-----------+-------------+
# |payment_mode|bill_id|bill_amount|running_total|
# +------------+-------+-----------+-------------+
# |        Cash|      3|       1500|         1500|
# |        Cash|      7|        850|         2350|
# |        Cash|     12|        900|         3250|
# |        Cash|     15|       1200|         4450|
# | Credit Card|      2|        800|          800|
# | Credit Card|      6|       2000|         2800|
# | Credit Card|     10|       1500|         4300|
# | Credit Card|     13|       2000|         6300|
# |  Debit Card|      5|       1300|         1300|
# |  Debit Card|     16|       1300|         2600|
# |         UPI|      1|       1200|         1200|
# |         UPI|      4|        900|         2100|
# |         UPI|      8|       1400|         3500|
# |         UPI|      9|        800|         4300|
# |         UPI|     11|       1200|         5500|
# |         UPI|     14|       1400|         6900|
# +------------+-------+-----------+-------------+

# %% [markdown]
# 95. Create running appointment count by doctor.

# %%
doctors.join(appointments, on = "doctor_id").groupBy("doctor_id", "doctor_name")
# Out:
# GroupedData[grouping expressions: [doctor_id, doctor_name], value: [doctor_id: int, doctor_name: string ... 7 more fields], type: GroupBy]

# %% [markdown]
# Section 11 — RDD Exercises
#
# Create RDD:
#
# logs = sc.textFile("hospital_logs.txt")
#
# 96. Count total log records.

# %%
from pyspark import SparkContext
sc = SparkContext.getOrCreate()

logs = sc.textFile("hospital_logs.txt")
logs.count()
# Out:
# 20

# %% [markdown]
# 97. Extract user names.

# %%
sc.textFile("hospital_logs.txt").map(lambda x: x.split(" ")[0]).collect()
# Out:
# ['Aarav',
#  'Priya',
#  'Rahul',
#  'Sneha',
#  'Aarav',
#  'Kiran',
#  'Meera',
#  'Vikram',
#  'Divya',
#  'Farhan',
#  'Simran',
#  'Neha',
#  'Amit',
#  'Rahul',
#  'Meera',
#  'Aarav',
#  'Priya',
#  'Divya',
#  'Vikram',
#  'Farhan']

# %%
user_names = logs.map(lambda line: line.split(" ")[0])
user_names.take(5)
# Out:
# ['Aarav', 'Priya', 'Rahul', 'Sneha', 'Aarav']

# %% [markdown]
# 98. Extract actions.

# %%
sc.textFile("hospital_logs.txt").map(lambda x: x.split(" ")[1]).collect()
# Out:
# ['login',
#  'login',
#  'appointment',
#  'login',
#  'payment',
#  'appointment',
#  'login',
#  'appointment',
#  'payment',
#  'login',
#  'appointment',
#  'payment',
#  'login',
#  'payment',
#  'appointment',
#  'logout',
#  'payment',
#  'login',
#  'payment',
#  'appointment']

# %% [markdown]
# 99. Find unique users.

# %%
sc.textFile("hospital_logs.txt").map(lambda x: x.split(" ")[0]).distinct().collect()
# Out:
# ['Kiran',
#  'Vikram',
#  'Divya',
#  'Simran',
#  'Amit',
#  'Aarav',
#  'Priya',
#  'Rahul',
#  'Sneha',
#  'Meera',
#  'Farhan',
#  'Neha']

# %% [markdown]
# 100. Count each action using map and reduceByKey .

# %%
user_names.map(lambda action: (action, 1)) \
                       .reduceByKey(lambda a, b: a + b)\
                       .collect()
# Out:
# [('Kiran', 1),
#  ('Vikram', 2),
#  ('Divya', 2),
#  ('Simran', 1),
#  ('Amit', 1),
#  ('Aarav', 3),
#  ('Priya', 2),
#  ('Rahul', 2),
#  ('Sneha', 1),
#  ('Meera', 2),
#  ('Farhan', 2),
#  ('Neha', 1)]

# %% [markdown]
# Bonus: Complex JSON Exercises
#
# Use patient_profiles.json .
#
# 1. Read the JSON file.
# .

# %%
from pyspark.sql.functions import col, explode

profiles = spark.read.json("patient_profiles.json", multiLine=True)

# %% [markdown]
# 2. Print schema.

# %%
profiles.printSchema()
# Out:
# root
#  |-- allergies: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- contact: struct (nullable = true)
#  |    |-- email: string (nullable = true)
#  |    |-- phone: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- patient_id: long (nullable = true)

# %% [markdown]
# 3. Extract patient_id, name, email, and phone.

# %%
profiles.select(
    col("patient_id"),
    col("name"),
    col("contact.email").alias("email"),
    col("contact.phone").alias("phone")
).show()
# Out:
# +----------+------+---------------+----------+
# |patient_id|  name|          email|     phone|
# +----------+------+---------------+----------+
# |         1| Aarav| aarav@mail.com|9000011111|
# |         2| Priya| priya@mail.com|9000022222|
# |         3| Rahul| rahul@mail.com|9000033333|
# |         6| Meera| meera@mail.com|9000066666|
# |        10|Vikram|vikram@mail.com|9000101010|
# +----------+------+---------------+----------+

# %% [markdown]
# 4. Explode allergies.

# %%
profiles_exploded = profiles.withColumn("allergy", explode(col("allergies")))

# %%
profiles_exploded.select("patient_id", "name", "allergy").show()
# Out:
# +----------+------+-------+
# |patient_id|  name|allergy|
# +----------+------+-------+
# |         1| Aarav|   Dust|
# |         1| Aarav|Peanuts|
# |         2| Priya| Pollen|
# |         3| Rahul|   Dust|
# |         3| Rahul|   Milk|
# |         6| Meera|Seafood|
# |        10|Vikram| Pollen|
# |        10|Vikram|   Dust|
# +----------+------+-------+

# %% [markdown]
# 5. Count patients by allergy.

# %%
patients_by_allergy = profiles_exploded.groupBy("allergy").count()
patients_by_allergy.show()
# Out:
# +-------+-----+
# |allergy|count|
# +-------+-----+
# |   Milk|    1|
# |   Dust|    3|
# |Peanuts|    1|
# | Pollen|    2|
# |Seafood|    1|
# +-------+-----+

# %% [markdown]
# 6. Find patients with Dust allergy.

# %%
patients_with_dust_allergy = profiles_exploded.filter(col("allergy") == "Dust")

patients_with_dust_allergy.select("patient_id", "name").show()
# Out:
# +----------+------+
# |patient_id|  name|
# +----------+------+
# |         1| Aarav|
# |         3| Rahul|
# |        10|Vikram|
# +----------+------+

# %% [markdown]
# 7. Find unique allergies.

# %%
profiles_exploded.select("allergy").distinct().show()
# Out:
# +-------+
# |allergy|
# +-------+
# |   Milk|
# |   Dust|
# |Peanuts|
# | Pollen|
# |Seafood|
# +-------+

# %% [markdown]
# 8. Join profiles with patients data.

# %%
patient_report = patients.join(profiles_exploded, on="patient_id", how="inner")
patient_report.show()
# Out:
# +----------+------+---------+---+------+-----------------+---------------+--------------------+------+-------+
# |patient_id|  name|     city|age|gender|registration_date|      allergies|             contact|  name|allergy|
# +----------+------+---------+---+------+-----------------+---------------+--------------------+------+-------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|[Dust, Peanuts]|{aarav@mail.com, ...| Aarav|   Dust|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|[Dust, Peanuts]|{aarav@mail.com, ...| Aarav|Peanuts|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|       [Pollen]|{priya@mail.com, ...| Priya| Pollen|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|   [Dust, Milk]|{rahul@mail.com, ...| Rahul|   Dust|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|   [Dust, Milk]|{rahul@mail.com, ...| Rahul|   Milk|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|      [Seafood]|{meera@mail.com, ...| Meera|Seafood|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01| [Pollen, Dust]|{vikram@mail.com,...|Vikram| Pollen|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01| [Pollen, Dust]|{vikram@mail.com,...|Vikram|   Dust|
# +----------+------+---------+---+------+-----------------+---------------+--------------------+------+-------+

# %% [markdown]
# 9. Show patient name, city, email, and allergy.

# %%
patients.join(profiles_exploded, on="patient_id") \
    .select(
        patients["name"],
        col("city"),
        col("contact.email").alias("email"),
        col("allergy")
    ).show()
# Out:
# +------+---------+---------------+-------+
# |  name|     city|          email|allergy|
# +------+---------+---------------+-------+
# | Aarav|Hyderabad| aarav@mail.com|   Dust|
# | Aarav|Hyderabad| aarav@mail.com|Peanuts|
# | Priya|Bangalore| priya@mail.com| Pollen|
# | Rahul|   Mumbai| rahul@mail.com|   Dust|
# | Rahul|   Mumbai| rahul@mail.com|   Milk|
# | Meera|Hyderabad| meera@mail.com|Seafood|
# |Vikram|   Mumbai|vikram@mail.com| Pollen|
# |Vikram|   Mumbai|vikram@mail.com|   Dust|
# +------+---------+---------------+-------+

# %% [markdown]
# 10. Count allergies per city

# %%
city_allergy_trends = patient_report.groupBy("city", "allergy").count()
city_allergy_trends.orderBy("city", col("count").desc()).show()
# Out:
# +---------+-------+-----+
# |     city|allergy|count|
# +---------+-------+-----+
# |Bangalore| Pollen|    1|
# |Hyderabad|Peanuts|    1|
# |Hyderabad|   Dust|    1|
# |Hyderabad|Seafood|    1|
# |   Mumbai|   Dust|    2|
# |   Mumbai|   Milk|    1|
# |   Mumbai| Pollen|    1|
# +---------+-------+-----+

# %% [markdown]
# Bonus: Spark SQL Exercises
#
# Create temp views:

# %%
patients.createOrReplaceTempView("patients")
doctors.createOrReplaceTempView("doctors")
appointments.createOrReplaceTempView("appointments")
bills.createOrReplaceTempView("bills")

# %% [markdown]
# Tasks:
# 1. Show all patients using SQL.

# %%
spark.sql("SELECT * FROM patients").show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 2. Show patients from Hyderabad.

# %%
spark.sql("SELECT * FROM patients WHERE city = 'Hyderabad'").show()
# Out:
# +----------+------+---------+---+------+-----------------+
# |patient_id|  name|     city|age|gender|registration_date|
# +----------+------+---------+---+------+-----------------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|
# +----------+------+---------+---+------+-----------------+

# %% [markdown]
# 3. Count patients by city.

# %%
spark.sql("SELECT city, COUNT(*) AS patient_count FROM patients GROUP BY city").show()
# Out:
# +---------+-------------+
# |     city|patient_count|
# +---------+-------------+
# |Bangalore|            2|
# |  Chennai|            1|
# |   Mumbai|            2|
# |     Pune|            1|
# |    Delhi|            3|
# |Hyderabad|            3|
# +---------+-------------+

# %% [markdown]
# 4. Count doctors by specialization.

# %%
spark.sql("SELECT specialization, COUNT(*) AS doctor_count FROM doctors GROUP BY specialization").show()
# Out:
# +--------------+------------+
# |specialization|doctor_count|
# +--------------+------------+
# |     Neurology|           1|
# |   Dermatology|           2|
# |    Cardiology|           2|
# |    Pediatrics|           1|
# |   Orthopedics|           2|
# +--------------+------------+

# %% [markdown]
# 5. Join patients and appointments.

# %%
spark.sql("SELECT * FROM patients JOIN appointments ON patients.patient_id = appointments.patient_id").show()
# Out:
# +----------+------+---------+---+------+-----------------+--------------+----------+---------+----------------+---------+
# |patient_id|  name|     city|age|gender|registration_date|appointment_id|patient_id|doctor_id|appointment_date|   status|
# +----------+------+---------+---+------+-----------------+--------------+----------+---------+----------------+---------+
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|             1|         1|      101|      2024-03-01|Completed|
# |         2| Priya|Bangalore| 34|Female|       2023-02-12|             2|         2|      102|      2024-03-01|Completed|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|             3|         3|      103|      2024-03-02|Completed|
# |         4| Sneha|    Delhi| 26|Female|       2023-04-15|             4|         4|      104|      2024-03-02|  Pending|
# |         5| Kiran|  Chennai| 37|  Male|       2023-05-11|             5|         5|      106|      2024-03-03|Completed|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|             6|         6|      105|      2024-03-03|Completed|
# |         7|  Amit|     Pune| 45|  Male|       2023-06-22|             7|         7|      107|      2024-03-04|Cancelled|
# |         8|  Neha|    Delhi| 28|Female|       2023-07-10|             8|         8|      108|      2024-03-04|Completed|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|             9|         9|      102|      2024-03-05|Completed|
# |        10|Vikram|   Mumbai| 52|  Male|       2023-08-01|            10|        10|      103|      2024-03-05|Completed|
# |        11|Farhan|Hyderabad| 39|  Male|       2023-08-10|            11|        11|      101|      2024-03-06|  Pending|
# |        12|Simran|    Delhi| 25|Female|       2023-08-21|            12|        12|      104|      2024-03-06|Completed|
# |         1| Aarav|Hyderabad| 29|  Male|       2023-01-10|            13|         1|      105|      2024-03-07|Completed|
# |         3| Rahul|   Mumbai| 41|  Male|       2023-03-14|            14|         3|      108|      2024-03-07|Completed|
# |         6| Meera|Hyderabad| 31|Female|       2023-06-10|            15|         6|      101|      2024-03-08|Cancelled|
# |         9| Divya|Bangalore| 33|Female|       2023-07-15|            16|         9|      106|      2024-03-08|Completed|
# +----------+------+---------+---+------+-----------------+--------------+----------+---------+----------------+---------+

# %% [markdown]
# 6. Join doctors and appointments.

# %%
spark.sql("SELECT * FROM doctors JOIN appointments ON doctors.doctor_id = appointments.doctor_id").show()
# Out:
# +---------+-----------+--------------+---------+----------------+--------------+----------+---------+----------------+---------+
# |doctor_id|doctor_name|specialization|     city|consultation_fee|appointment_id|patient_id|doctor_id|appointment_date|   status|
# +---------+-----------+--------------+---------+----------------+--------------+----------+---------+----------------+---------+
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|             1|         1|      101|      2024-03-01|Completed|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|             2|         2|      102|      2024-03-01|Completed|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|             3|         3|      103|      2024-03-02|Completed|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|             4|         4|      104|      2024-03-02|  Pending|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|             5|         5|      106|      2024-03-03|Completed|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|             6|         6|      105|      2024-03-03|Completed|
# |      107|   Dr Verma|   Dermatology|     Pune|             850|             7|         7|      107|      2024-03-04|Cancelled|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|             8|         8|      108|      2024-03-04|Completed|
# |      102|    Dr Iyer|   Dermatology|Bangalore|             800|             9|         9|      102|      2024-03-05|Completed|
# |      103|    Dr Khan|   Orthopedics|   Mumbai|            1500|            10|        10|      103|      2024-03-05|Completed|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|            11|        11|      101|      2024-03-06|  Pending|
# |      104|   Dr Reddy|    Pediatrics|    Delhi|             900|            12|        12|      104|      2024-03-06|Completed|
# |      105|   Dr Mehta|     Neurology|Hyderabad|            2000|            13|         1|      105|      2024-03-07|Completed|
# |      108|     Dr Rao|   Orthopedics|    Delhi|            1400|            14|         3|      108|      2024-03-07|Completed|
# |      101|  Dr Sharma|    Cardiology|Hyderabad|            1200|            15|         6|      101|      2024-03-08|Cancelled|
# |      106|    Dr Nair|    Cardiology|  Chennai|            1300|            16|         9|      106|      2024-03-08|Completed|
# +---------+-----------+--------------+---------+----------------+--------------+----------+---------+----------------+---------+

# %% [markdown]
# 7. Join appointments and bills.

# %%
spark.sql("SELECT * FROM appointments JOIN bills ON appointments.appointment_id = bills.appointment_id").show()
# Out:
# +--------------+----------+---------+----------------+---------+-------+--------------+-----------+------------+--------------+
# |appointment_id|patient_id|doctor_id|appointment_date|   status|bill_id|appointment_id|bill_amount|payment_mode|payment_status|
# +--------------+----------+---------+----------------+---------+-------+--------------+-----------+------------+--------------+
# |             1|         1|      101|      2024-03-01|Completed|      1|             1|       1200|         UPI|          Paid|
# |             2|         2|      102|      2024-03-01|Completed|      2|             2|        800| Credit Card|          Paid|
# |             3|         3|      103|      2024-03-02|Completed|      3|             3|       1500|        Cash|          Paid|
# |             4|         4|      104|      2024-03-02|  Pending|      4|             4|        900|         UPI|       Pending|
# |             5|         5|      106|      2024-03-03|Completed|      5|             5|       1300|  Debit Card|          Paid|
# |             6|         6|      105|      2024-03-03|Completed|      6|             6|       2000| Credit Card|          Paid|
# |             7|         7|      107|      2024-03-04|Cancelled|      7|             7|        850|        Cash|     Cancelled|
# |             8|         8|      108|      2024-03-04|Completed|      8|             8|       1400|         UPI|          Paid|
# |             9|         9|      102|      2024-03-05|Completed|      9|             9|        800|         UPI|          Paid|
# |            10|        10|      103|      2024-03-05|Completed|     10|            10|       1500| Credit Card|          Paid|
# |            11|        11|      101|      2024-03-06|  Pending|     11|            11|       1200|         UPI|       Pending|
# |            12|        12|      104|      2024-03-06|Completed|     12|            12|        900|        Cash|          Paid|
# |            13|         1|      105|      2024-03-07|Completed|     13|            13|       2000| Credit Card|          Paid|
# |            14|         3|      108|      2024-03-07|Completed|     14|            14|       1400|         UPI|          Paid|
# |            15|         6|      101|      2024-03-08|Cancelled|     15|            15|       1200|        Cash|     Cancelled|
# |            16|         9|      106|      2024-03-08|Completed|     16|            16|       1300|  Debit Card|          Paid|
# +--------------+----------+---------+----------------+---------+-------+--------------+-----------+------------+--------------+

# %% [markdown]
# 8. Find total bill amount by payment mode.

# %%
spark.sql("""
    SELECT payment_mode, sum(bill_amount) as total_collected
    FROM bills
    GROUP BY payment_mode
""").show()
# Out:
# +------------+---------------+
# |payment_mode|total_collected|
# +------------+---------------+
# | Credit Card|           6300|
# |        Cash|           4450|
# |  Debit Card|           2600|
# |         UPI|           6900|
# +------------+---------------+

# %% [markdown]
# 9. Rank doctors by consultation fee using SQL.

# %%
spark.sql("SELECT doctor_id, doctor_name, consultation_fee, RANK() OVER (ORDER BY consultation_fee) AS rank FROM doctors").show()
# Out:
# +---------+-----------+----------------+----+
# |doctor_id|doctor_name|consultation_fee|rank|
# +---------+-----------+----------------+----+
# |      102|    Dr Iyer|             800|   1|
# |      107|   Dr Verma|             850|   2|
# |      104|   Dr Reddy|             900|   3|
# |      101|  Dr Sharma|            1200|   4|
# |      106|    Dr Nair|            1300|   5|
# |      108|     Dr Rao|            1400|   6|
# |      103|    Dr Khan|            1500|   7|
# |      105|   Dr Mehta|            2000|   8|
# +---------+-----------+----------------+----+

# %% [markdown]
# 10. Find top billing patient using SQL.

# %%
spark.sql("""
    SELECT p.name, sum(b.bill_amount) as total_spent
    FROM patients p
    JOIN appointments a ON p.patient_id = a.patient_id
    JOIN bills b ON a.appointment_id = b.appointment_id
    GROUP BY p.name
    ORDER BY total_spent DESC
    LIMIT 1
""").show()
# Out:
# +-----+-----------+
# | name|total_spent|
# +-----+-----------+
# |Meera|       3200|
# +-----+-----------+
